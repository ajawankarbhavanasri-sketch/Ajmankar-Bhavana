# %% [markdown]
# <a href="https://colab.research.google.com/github/ajawankarbhavanasri-sketch/Ajmankar-Bhavana/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/flyrank-bih/flyrank-ml-internship-starter/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# I selected the Content Decline Risk lane because I want to identify pages whose impressions are falling and help prioritize them for human review. This is useful because the dataset contains recent and previous 30-day impression measures that can be used to study content performance changes.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
lane = "Content Decline Risk"
print("Selected lane:", lane)
# Out:
# Selected lane: Content Decline Risk

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*
#
# The decision is which pages should be reviewed first when their impressions decline by more than 20%. Content or SEO teams can use the results to prioritize human review. A wrong recommendation could waste review time on healthy pages or cause a genuinely declining page to be missed, so the model should support human decisions rather than replace them.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
decline_threshold = 0.20

print(f"Decline threshold: {decline_threshold:.0%}")
print("Use case: prioritize pages for human review")
# Out:
# Decline threshold: 20%
# Use case: prioritize pages for human review

# %%
import pandas as pd

csv_path = "flyrank-ml-internship-starter/data/raw/content_refresh_anonymized.csv"

df = pd.read_csv(csv_path)

print("Loaded:", csv_path)
print("Rows:", len(df))
print("Columns:", len(df.columns))
# Out:
# Loaded: flyrank-ml-internship-starter/data/raw/content_refresh_anonymized.csv
# Rows: 30000
# Columns: 44

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*
#
# The starter dataset contains 30,000 content records. Average impressions were 1,429.1 in the last 30 days compared with 1,783.1 in the previous 30 days. This observed difference makes content decline worth investigating further.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Basic checks for the Content Decline Risk lane

print(f"Content records: {len(df):,}")
print(f"Average impressions in last 30 days: {df['impressions_last_30d'].mean():,.1f}")
print(f"Average impressions in previous 30 days: {df['impressions_prev_30d'].mean():,.1f}")
# Out:
# Content records: 30,000
# Average impressions in last 30 days: 1,429.1
# Average impressions in previous 30 days: 1,783.1

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*
#
# This work will measure observed changes in content impressions and identify directional signals related to content decline. The results can support decisions about which pages should be prioritized for human review. The model will not prove that any feature caused a decline, and it will not predict Google's ranking decisions. The results are decision-support, not causal proof or a guarantee of future performance.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
print("Claim type: observed and directional")
print("Use: decision-support for prioritizing pages for human review")
print("Limit: not causal proof and not a prediction of Google's ranking decisions")
# Out:
# Claim type: observed and directional
# Use: decision-support for prioritizing pages for human review
# Limit: not causal proof and not a prediction of Google's ranking decisions

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
